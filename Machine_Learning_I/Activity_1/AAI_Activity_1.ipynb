# %% [markdown]
# # Aprendizaje Automático I
# ## Actividad 1
# ### Joan Calabuig Artés

# %% [markdown]
# En este documento se realiza una tarea de clasificación según el tipo de alojamiento a partir del resto de caracteristicas.
#
# Los pasos que sigue el documentos son los siguientes:
#
# 1.   Estudio estadístico
# 2.   Limpieza de datos
# 3.   Entrenamiento
# 4.   Validación
# 3.   Conclusión

# %% [markdown]
# Se inicia el proceso de clasificación cargando las librerias nececarias.
# A continuación, se carga el archivo de datos.

# %%
import pandas as pd
import requests
import io
import sklearn
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv("./sample_data/airbnb.csv")
dataframe.head()
# Out:
#   neighbourhood_group  neighbourhood   latitude  longitude        room_type  \
# 0              Centro       Justicia  40.424715  -3.698638  Entire home/apt
# 1              Centro    Embajadores  40.413418  -3.706838  Entire home/apt
# 2   Moncloa - Aravaca      Argüelles  40.424920  -3.713446  Entire home/apt
# 3   Moncloa - Aravaca  Casa de Campo  40.431027  -3.724586  Entire home/apt
# 4              Latina       Cármenes  40.403410  -3.740842     Private room
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0     49              28                 35               0.42
# 1     80               5                 18               0.30
# 2     40               2                 21               0.25
# 3     55               2                  3               0.13
# 4     16               2                 23               0.76
#
#    calculated_host_listings_count  availability_365
# 0                               1                99
# ...
